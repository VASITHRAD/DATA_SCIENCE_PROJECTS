# %% [markdown]
# # UNEMPLOYMENT ANALYSIS

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\vasit\Downloads\Unemployment in India.csv")

# %%
df
# Out:
#              Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh   31-05-2019    Monthly                              3.65
# 1    Andhra Pradesh   30-06-2019    Monthly                              3.05
# 2    Andhra Pradesh   31-07-2019    Monthly                              3.75
# 3    Andhra Pradesh   31-08-2019    Monthly                              3.32
# 4    Andhra Pradesh   30-09-2019    Monthly                              5.17
# ..              ...          ...        ...                               ...
# 763             NaN          NaN        NaN                               NaN
# 764             NaN          NaN        NaN                               NaN
# 765             NaN          NaN        NaN                               NaN
# 766             NaN          NaN        NaN                               NaN
# 767             NaN          NaN        NaN                               NaN
#
# ...

# %%
df.rename(columns={"Region": "region", " Date": "date", " Frequency": "frequency", " Estimated Unemployment Rate (%)": "unemployment_rate", " Estimated Employed": "employed", " Estimated Labour Participation Rate (%)": "labour_participate_rate", "Area": "area"},inplace=True)

# %%
df
# Out:
#              region         date frequency  unemployment_rate    employed  \
# 0    Andhra Pradesh   31-05-2019   Monthly               3.65  11999139.0
# 1    Andhra Pradesh   30-06-2019   Monthly               3.05  11755881.0
# 2    Andhra Pradesh   31-07-2019   Monthly               3.75  12086707.0
# 3    Andhra Pradesh   31-08-2019   Monthly               3.32  12285693.0
# 4    Andhra Pradesh   30-09-2019   Monthly               5.17  12256762.0
# ..              ...          ...       ...                ...         ...
# 763             NaN          NaN       NaN                NaN         NaN
# 764             NaN          NaN       NaN                NaN         NaN
# 765             NaN          NaN       NaN                NaN         NaN
# 766             NaN          NaN       NaN                NaN         NaN
# 767             NaN          NaN       NaN                NaN         NaN
#
#      labour_participate_rate   area
# 0                      43.24  Rural
# ...

# %%
df.head
# Out:
# <bound method NDFrame.head of      index          region         date frequency  unemployment_rate  \
# 0        0  Andhra Pradesh   31-05-2019   Monthly               3.65
# 1        1  Andhra Pradesh   30-06-2019   Monthly               3.05
# 2        2  Andhra Pradesh   31-07-2019   Monthly               3.75
# 3        3  Andhra Pradesh   31-08-2019   Monthly               3.32
# 4        4  Andhra Pradesh   30-09-2019   Monthly               5.17
# ..     ...             ...          ...       ...                ...
# 735    749     West Bengal   29-02-2020   Monthly               7.55
# 736    750     West Bengal   31-03-2020   Monthly               6.67
# 737    751     West Bengal   30-04-2020   Monthly              15.63
# 738    752     West Bengal   31-05-2020   Monthly              15.22
# 739    753     West Bengal   30-06-2020   Monthly               9.86
#
#        employed  labour_participate_rate   area  year
# 0    11999139.0                    43.24  Rural  2019
# ...

# %%
df.tail
# Out:
# <bound method NDFrame.tail of      index          region         date frequency  unemployment_rate  \
# 0        0  Andhra Pradesh   31-05-2019   Monthly               3.65
# 1        1  Andhra Pradesh   30-06-2019   Monthly               3.05
# 2        2  Andhra Pradesh   31-07-2019   Monthly               3.75
# 3        3  Andhra Pradesh   31-08-2019   Monthly               3.32
# 4        4  Andhra Pradesh   30-09-2019   Monthly               5.17
# ..     ...             ...          ...       ...                ...
# 735    749     West Bengal   29-02-2020   Monthly               7.55
# 736    750     West Bengal   31-03-2020   Monthly               6.67
# 737    751     West Bengal   30-04-2020   Monthly              15.63
# 738    752     West Bengal   31-05-2020   Monthly              15.22
# 739    753     West Bengal   30-06-2020   Monthly               9.86
#
#        employed  labour_participate_rate   area  year
# 0    11999139.0                    43.24  Rural  2019
# ...

# %%
df.region.unique()
# Out:
# array(['Andhra Pradesh', 'Assam', 'Bihar', 'Chhattisgarh', 'Delhi', 'Goa',
#        'Gujarat', 'Haryana', 'Himachal Pradesh', 'Jammu & Kashmir',
#        'Jharkhand', 'Karnataka', 'Kerala', 'Madhya Pradesh',
#        'Maharashtra', 'Meghalaya', 'Odisha', 'Puducherry', 'Punjab',
#        'Rajasthan', 'Sikkim', 'Tamil Nadu', 'Telangana', 'Tripura',
#        'Uttar Pradesh', 'Uttarakhand', 'West Bengal', nan, 'Chandigarh'],
#       dtype=object)

# %%
df.area.unique()
# Out:
# array(['Rural', nan, 'Urban'], dtype=object)

# %%
df=df.dropna()
df
# Out:
#      index          region         date frequency  unemployment_rate  \
# 0        0  Andhra Pradesh   31-05-2019   Monthly               3.65
# 1        1  Andhra Pradesh   30-06-2019   Monthly               3.05
# 2        2  Andhra Pradesh   31-07-2019   Monthly               3.75
# 3        3  Andhra Pradesh   31-08-2019   Monthly               3.32
# 4        4  Andhra Pradesh   30-09-2019   Monthly               5.17
# ..     ...             ...          ...       ...                ...
# 735    749     West Bengal   29-02-2020   Monthly               7.55
# 736    750     West Bengal   31-03-2020   Monthly               6.67
# 737    751     West Bengal   30-04-2020   Monthly              15.63
# 738    752     West Bengal   31-05-2020   Monthly              15.22
# 739    753     West Bengal   30-06-2020   Monthly               9.86
#
#        employed  labour_participate_rate   area  year
# 0    11999139.0                    43.24  Rural  2019
# ...

# %% [markdown]
# # PROCESSED DATA

# %%
df
# Out:
#              region         date frequency  unemployment_rate    employed  \
# 0    Andhra Pradesh   31-05-2019   Monthly               3.65  11999139.0
# 1    Andhra Pradesh   30-06-2019   Monthly               3.05  11755881.0
# 2    Andhra Pradesh   31-07-2019   Monthly               3.75  12086707.0
# 3    Andhra Pradesh   31-08-2019   Monthly               3.32  12285693.0
# 4    Andhra Pradesh   30-09-2019   Monthly               5.17  12256762.0
# ..              ...          ...       ...                ...         ...
# 749     West Bengal   29-02-2020   Monthly               7.55  10871168.0
# 750     West Bengal   31-03-2020   Monthly               6.67  10806105.0
# 751     West Bengal   30-04-2020   Monthly              15.63   9299466.0
# 752     West Bengal   31-05-2020   Monthly              15.22   9240903.0
# 753     West Bengal   30-06-2020   Monthly               9.86   9088931.0
#
#      labour_participate_rate   area
# 0                      43.24  Rural
# ...

# %%
df.describe()
# Out:
#        unemployment_rate      employed  labour_participate_rate
# count         740.000000  7.400000e+02               740.000000
# mean           11.787946  7.204460e+06                42.630122
# std            10.721298  8.087988e+06                 8.111094
# min             0.000000  4.942000e+04                13.330000
# 25%             4.657500  1.190404e+06                38.062500
# 50%             8.350000  4.744178e+06                41.160000
# 75%            15.887500  1.127549e+07                45.505000
# max            76.740000  4.577751e+07                72.570000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 740 entries, 0 to 753
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   region                   740 non-null    object
#  1   date                     740 non-null    object
#  2   frequency                740 non-null    object
#  3   unemployment_rate        740 non-null    float64
#  4   employed                 740 non-null    float64
#  5   labour_participate_rate  740 non-null    float64
#  6   area                     740 non-null    object
# dtypes: float64(3), object(4)
# memory usage: 46.2+ KB

# %% [markdown]
# # DATA ANALYSIS

# %% [markdown]
# ### PAIR PLOT

# %%
import matplotlib.pyplot as plt
import seaborn as sns

cols = ["unemployment_rate", "employed", "labour_participate_rate"]

print("Relationship between the employment, unemployment rates and the labour participation rate")

sns.pairplot(df[cols])
# Out:
# Relationship between the employment, unemployment rates and the labour participation rate

# %% [markdown]
# ### PIE CHART

# %%
# group data by region and calculate average unemployment rate

avg_unemployment = df.groupby('region')['unemployment_rate'].mean()

fig, ax = plt.subplots(figsize=(12, 12))
ax.pie(avg_unemployment, labels=avg_unemployment.index, autopct='%2.1f%%')
ax.set_title('Average Unemployment Rate by Region')

plt.show()

# %% [markdown]
# ### SCATTER PLOT

# %%
plt.rcParams["figure.figsize"] = (20, 20)
plt.scatter(df['date'], df['unemployment_rate'])
plt.title('Unemployment Rate by Date',size=20)
plt.xlabel('Date',size=20)
plt.ylabel('Unemployment Rate (%)',size=20)
plt.show()

# %% [markdown]
# ### BAR PLOT

# %%
plt.rcParams["figure.figsize"] = (10, 10)
sns.barplot(x='region', y='unemployment_rate', data=df)
plt.title('Unemployment Rate by Region',size=10)
plt.xlabel('Region',size=10)
plt.ylabel('Unemployment Rate (%)',size=10)
bar_plot = sns.barplot(x='region', y='unemployment_rate', data=df)
bar_plot.set_xticklabels(bar_plot.get_xticklabels(), rotation=50) 
plt.show()

# %% [markdown]
# ### BOX PLOT

# %%
sns.set_style("whitegrid")
fig, ax = plt.subplots(figsize=(30, 30))
sns.boxplot(data=df, x="region", y="unemployment_rate", hue="frequency", ax=ax)
ax.set_title("Unemployment Rate by Region and Frequency",size=30)
ax.set_ylabel("Unemployment Rate",size=30)
ax.set_xlabel("\nRegion",size=30)
plt.xticks(rotation=90)
ax.set_xticklabels(ax.get_xticklabels(), fontsize=30)
plt.subplots_adjust(wspace=1)
plt.show()

# %% [markdown]
# ### HEAT MAP

# %%
corr = df.corr(numeric_only=True)
sns.heatmap(corr, annot=True, cmap="coolwarm")
plt.show()

# %%
df_pivot = pd.pivot_table(df, values='unemployment_rate', index='region', columns='date', aggfunc='mean')

plt.figure(figsize=(20, 20))
sns.heatmap(df_pivot, cmap='YlGnBu')
plt.title('Unemployment Rate by Region and Date',size=20)
plt.xlabel('Date',size=20)
plt.ylabel('Region',size=20)
plt.show()

# %%
# Print the first 5 rows to check the data 
print(df.head())
print("\n\n")

# Get some basic statistics on the unemployment rate column
print(df['unemployment_rate'].describe())
print("\n")

# average unemployment rate for each region
region_avg_unemp = df.groupby('region')['unemployment_rate'].mean()
print("Avg unemployment in each region:\n\n",region_avg_unemp)
print("\n\n")

# overall average unemployment rate for the entire dataset
overall_avg_unemp = df['unemployment_rate'].mean()
print("Overall average unemployment rate:", overall_avg_unemp)
print("\n\n")

# average unemployment rate by year
df['year'] = pd.DatetimeIndex(df['date']).year
yearly_avg_unemp = df.groupby('year')['unemployment_rate'].mean()
print("yearly avg unemployment: \n",yearly_avg_unemp)
# Out:
#    level_0  index          region         date frequency  unemployment_rate  \
# 0        0      0  Andhra Pradesh   31-05-2019   Monthly               3.65
# 1        1      1  Andhra Pradesh   30-06-2019   Monthly               3.05
# 2        2      2  Andhra Pradesh   31-07-2019   Monthly               3.75
# 3        3      3  Andhra Pradesh   31-08-2019   Monthly               3.32
# 4        4      4  Andhra Pradesh   30-09-2019   Monthly               5.17
#
#      employed  labour_participate_rate   area  year
# 0  11999139.0                    43.24  Rural  2019
# 1  11755881.0                    42.05  Rural  2019
# 2  12086707.0                    43.50  Rural  2019
# 3  12285693.0                    43.97  Rural  2019
# 4  12256762.0                    44.68  Rural  2019
#
#
#
# count    740.000000
# mean      11.787946
# std       10.721298
# min        0.000000
# 25%        4.657500
# 50%        8.350000
# 75%       15.887500
# max       76.740000
# ...

# %% [markdown]
# # CONCLUSION

# %% [markdown]
# ### The dataset on unemployment was analyzed, revealing that the average unemployment rate for all regions and time periods combined was 11.79%. Bihar had the highest average unemployment rate, standing at 18.92%, while Meghalaya had the lowest at 4.80%. On average, the dataset's overall unemployment rate was 11.79%. Further examination of yearly averages showed that in 2019, the unemployment rate was lower at 9.40% compared to 2020, where it reached 15.10%..
